# %% [markdown]
# # Basics of text processing
#
# ### Natural Language Processing and Information Extraction,  2021 WS
# 10/15/2021
#
# Gábor Recski

# %% [markdown]
# ## In this lecture
# - Regular Expressions
#
# - Text segmentation and normalization:
#    - sentence splitting and tokenization
#    - lemmatization, stemming, decompounding, morphology

# %% [markdown]
# ## Import dependencies

# %%
# !pip install stanza
# !pip install nltk
# !pip install bash-kernel
# !python -m bash_kernel.install

# %%
import re
from collections import Counter

import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
import stanza
stanza.download('en')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-10-14 19:10:38 INFO: Downloading default packages for language: en (English)...
# 2021-10-14 19:10:39 INFO: File exists: /home/jovyan/stanza_resources/en/default.zip.
# 2021-10-14 19:10:43 INFO: Finished downloading models and saved to /home/jovyan/stanza_resources.

# %% [markdown]
# ## Regular expressions

# %% [markdown]
# ### Basics

# %% [markdown]
# ![re1](media/re1.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %%
re.findall('a', "Mary Ann stopped by Mona's")
# Out:
# ['a', 'a']

# %%
text = open('data/alice_de.txt').read()
print(text[:100])
# Out:
# [1] Erstes Kapitel.
#
# Hinunter in den Kaninchenbau.
#
# Alice fing an sich zu langweilen; sie saß schon

# %%
re.search('Alice', text)
# Out:
# <re.Match object; span=(52, 57), match='Alice'>

# %%
text[52:57]
# Out:
# 'Alice'

# %% [markdown]
# ![re2](media/re2.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %%
re.search('[Kk]aninchen', text)
# Out:
# <re.Match object; span=(37, 46), match='Kaninchen'>

# %%
re.findall('[Kk]aninchen', text[:5000])
# Out:
# ['Kaninchen', 'Kaninchen', 'Kaninchen', 'Kaninchen', 'Kaninchen', 'Kaninchen']

# %%
for match in re.finditer('[Kk]aninchen', text[:5000]):
    print(match.group(), match.span())
# Out:
# Kaninchen (37, 46)
# Kaninchen (548, 557)
# Kaninchen (700, 709)
# Kaninchen (924, 933)
# Kaninchen (1073, 1082)
# Kaninchen (1453, 1462)

# %% [markdown]
# ![re3](media/re3.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %%
re.findall(' [A-Za-z][a-z][a-z] ', text[:5000])
# Out:
# [' den ',
#  ' sie ',
#  ' bei ',
#  ' und ',
#  ' Das ',
#  ' das ',
#  ' ihr ',
#  ' was ',
#  ' und ',
#  ' gut ',
#  ' sie ',
#  ' und ',
#  ' von ',
#  ' der ',
#  ' sei ',
#  ' und ',
#  ' als ',
#  ' ein ',
#  ' mit ',
#  ' ihr ',
#  ' war ',
#  ' sie ',
#  ' Ich ',
#  ' sie ',
#  ' ihr ',
#  ' sie ',
#  ' zur ',
#  ' kam ',
#  ' ihr ',
#  ' als ',
#  ' Uhr ',
#  ' der ',
#  ' der ',
#  ' sah ',
#  ' war ',
#  ' nie ',
#  ' ein ',
#  ' mit ',
#  ' und ',
#  ' Uhr ',
#  ' Vor ',
#  ' sie ',
#  ' den ',
#  ' und ',
#  ' zur ',
#  ' ein ',
#  ' der ',
#  ' war ',
#  ' ihm ',
#  ' das ',
#  ' wie ',
#  ' sie ',
#  ' zum ',
#  ' wie ',
#  ' und ',
#  ' ehe ',
#  ' den ',
#  ' sie ',
#  ' sie ',
#  ' wie ',
#  ' der ',
#  ' sie ',
#  ' sie ',
#  ' und ',
#  ' was ',
#  ' sie ',
#  ' sie ',
#  ' war ',
#  ' sie ',
#  ' des ',
#  ' und ',
#  ' sie ',
#  ' und ',
#  ' und ',
#  ' sie ',
#  ' und ',
#  ' Sie ',
#  ' von ',
#  ' der ',
#  ' ein ',
#  ' mit ',
#  ' war ',
#  ' Sie ',
#  ' aus ',
#  ' und ',
#  ' dem ',
#  ' bei ',
#  ' ich ',
#  ' ich ',
#  ' Wie ',
#  ' sie ',
#  ' Ich ',
#  ' ich ',
#  ' von ',
#  ' der ',
#  ' nie ',
#  ' ich ',
#  ' sie ',
#  ' der ',
#  ' das ',
#  ' und ',
#  ' ich ',
#  ' ihr ',
#  ' der ',
#  ' und ',
#  ' zum ',
#  ' sie ',
#  ' das ',
#  ' die ',
#  ' und ',
#  ' ich ',
#  ' den ',
#  ' was ',
#  ' ihr ',
#  ' und ',
#  ' sie ',
#  ' ich ',
#  ' die ',
#  ' Wie ',
#  ' das ',
#  ' bei ',
#  ' die ',
#  ' dem ',
#  ' die ',
#  ' war ',
#  ' ihr ',
#  ' das ',
#  ' ihr ',
#  ' ich ',
#  ' wie ',
#  ' ist ',
#  ' sie ',
#  ' man ',
#  ' die ',
#  ' ihr ',
#  ' sie ',
#  ' ein ',
#  ' ich ',
#  ' ich ',
#  ' Sie ',
#  ' war ',
#  ' sie ',
#  ' zur ',
#  ' ich ',
#  ' bei ',
#  ' Mir ',
#  ' nur ',
#  ' der ',
#  ' die ',
#  ' der ',
#  ' Und ',
#  ' und ',
#  ' Und ',
#  ' ihr ',
#  ' kam ',
#  ' gar ',
#  ' wie ',
#  ' die ',
#  ' Sie ',
#  ' sie ',
#  ' und ',
#  ' sie ']

# %%
Counter(re.findall(' [A-Za-z][a-z][a-z] ', text)).most_common(10)
# Out:
# [(' und ', 659),
#  (' sie ', 550),
#  (' die ', 493),
#  (' der ', 405),
#  (' ich ', 259),
#  (' das ', 212),
#  (' mit ', 170),
#  (' den ', 151),
#  (' ist ', 138),
#  (' war ', 128)]

# %% [markdown]
# ![re4](media/re4.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %% [markdown]
# ![re5](media/re5.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %% [markdown]
# ![re6](media/re6.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %%
re.findall('...', text[:100])
# Out:
# ['[1]',
#  ' Er',
#  'ste',
#  's K',
#  'api',
#  'tel',
#  'Hin',
#  'unt',
#  'er ',
#  'in ',
#  'den',
#  ' Ka',
#  'nin',
#  'che',
#  'nba',
#  'Ali',
#  'ce ',
#  'fin',
#  'g a',
#  'n s',
#  'ich',
#  ' zu',
#  ' la',
#  'ngw',
#  'eil',
#  'en;',
#  ' si',
#  'e s',
#  'aß ',
#  'sch',
#  'on ']

# %% [markdown]
# ![re7](media/re7.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %%
re.findall('\w', text[:50])
# Out:
# ['1',
#  'E',
#  'r',
#  's',
#  't',
#  'e',
#  's',
#  'K',
#  'a',
#  'p',
#  'i',
#  't',
#  'e',
#  'l',
#  'H',
#  'i',
#  'n',
#  'u',
#  'n',
#  't',
#  'e',
#  'r',
#  'i',
#  'n',
#  'd',
#  'e',
#  'n',
#  'K',
#  'a',
#  'n',
#  'i',
#  'n',
#  'c',
#  'h',
#  'e',
#  'n',
#  'b',
#  'a',
#  'u']

# %%
re.split('\s', text[:100])
# Out:
# ['[1]',
#  'Erstes',
#  'Kapitel.',
#  '',
#  'Hinunter',
#  'in',
#  'den',
#  'Kaninchenbau.',
#  '',
#  'Alice',
#  'fing',
#  'an',
#  'sich',
#  'zu',
#  'langweilen;',
#  'sie',
#  'saß',
#  'schon',
#  '']

# %% [markdown]
# ![re8](media/re8.png)([SLP Ch.2](https://web.stanford.edu/~jurafsky/slp3/2.pdf))

# %%
re.findall('(\w+)', text[:100])
# Out:
# ['1',
#  'Erstes',
#  'Kapitel',
#  'Hinunter',
#  'in',
#  'den',
#  'Kaninchenbau',
#  'Alice',
#  'fing',
#  'an',
#  'sich',
#  'zu',
#  'langweilen',
#  'sie',
#  'saß',
#  'schon']

# %%
Counter(re.findall('\w+', text)).most_common(20)
# Out:
# [('sie', 778),
#  ('und', 742),
#  ('die', 620),
#  ('der', 477),
#  ('zu', 421),
#  ('Alice', 388),
#  ('ich', 360),
#  ('sagte', 360),
#  ('es', 357),
#  ('nicht', 352),
#  ('das', 301),
#  ('sich', 284),
#  ('in', 279),
#  ('war', 218),
#  ('so', 213),
#  ('den', 207),
#  ('ein', 207),
#  ('mit', 204),
#  ('ist', 197),
#  ('an', 182)]

# %%
Counter(re.findall('[^\w\s]', text)).most_common(20)
# Out:
# [(',', 2617),
#  ('„', 1086),
#  ('“', 1083),
#  ('.', 1045),
#  ('!', 466),
#  (';', 275),
#  ('–', 222),
#  (':', 215),
#  ('?', 208),
#  ('[', 180),
#  (']', 180),
#  ('’', 108),
#  ('(', 55),
#  (')', 55),
#  ('-', 33),
#  ('‚', 10),
#  ('‘', 10),
#  ('*', 3),
#  ('↑', 2)]

# %% [markdown]
# ### Substitution and groups

# %%
re.sub('\s+', ' ', text[:100])
# Out:
# '[1] Erstes Kapitel. Hinunter in den Kaninchenbau. Alice fing an sich zu langweilen; sie saß schon '

# %%
print(re.sub('\s+', '\n', text[:100]))
# Out:
# [1]
# Erstes
# Kapitel.
# Hinunter
# in
# den
# Kaninchenbau.
# Alice
# fing
# an
# sich
# zu
# langweilen;
# sie
# saß
# schon

# %%
re.findall('[^\s]+ [^\s]+ Kapitel.', text)
# Out:
# ['[1] Erstes Kapitel.',
#  '[14] Zweites Kapitel.',
#  '[27] Drittes Kapitel.',
#  '[39] Viertes Kapitel.',
#  '[55] Fünftes Kapitel.',
#  '[71] Sechstes Kapitel.',
#  '[88] Siebentes Kapitel.',
#  '[104] Achtes Kapitel.',
#  '[121] Neuntes Kapitel.',
#  '[137] Zehntes Kapitel.',
#  '[150] Elftes Kapitel.',
#  '[163] Zwölftes Kapitel.']

# %%
print(re.sub('\[([0-9]+)\] ([^\s]+) Kapitel.', '\\2 Kapitel (\\1):', text[:100]))
# Out:
# Erstes Kapitel (1):
#
# Hinunter in den Kaninchenbau.
#
# Alice fing an sich zu langweilen; sie saß schon

# %%
print(re.sub('CHAPTER ([^\s.]+).\n([^\n]*)', 'Chapter \\1: \\2', text[:100]))
# Out:
# Chapter I: Down the Rabbit-Hole
#
#
# Alice was beginning to get very tired of sitting by her sister on

# %%
re.findall('\[([0-9]+)\] ([^\s]+) Kapitel.', text)
# Out:
# [('1', 'Erstes'),
#  ('14', 'Zweites'),
#  ('27', 'Drittes'),
#  ('39', 'Viertes'),
#  ('55', 'Fünftes'),
#  ('71', 'Sechstes'),
#  ('88', 'Siebentes'),
#  ('104', 'Achtes'),
#  ('121', 'Neuntes'),
#  ('137', 'Zehntes'),
#  ('150', 'Elftes'),
#  ('163', 'Zwölftes')]

# %% [markdown]
# Regular expressions are surprisingly powerful. Also, with the right implementation, they are literally as fast as you can get. That's because they are equivalent to [finite state automata (FSAs)](https://en.wikipedia.org/wiki/Finite-state_machine). Actually, every regular expression is a [regular grammar](https://en.wikipedia.org/wiki/Regular_grammar) defining a [regular language](https://en.wikipedia.org/wiki/Regular_language).

# %% [markdown]
# ![re_xkcd](media/re_xkcd.png)([XKCD #208](https://xkcd.com/208/))

# %% [markdown]
# ## Text segmentation

# %% [markdown]
# ### Sentence splitting

# %% [markdown]
# #### How to split a text into sentences?

# %%
text2 = "'Of course it's only because Tom isn't home,' said Mrs. Parsons vaguely."

# %% [markdown]
# Naive: split on `.`, `!`, `?`, etc.

# %%
re.split('[.!?]', text2)
# Out:
# ["'Of course it's only because Tom isn't home,' said Mrs",
#  ' Parsons vaguely',
#  '']

# %% [markdown]
# Better: use language-specific list of abbreviation words, collocations, etc.

# %%
nltk.sent_tokenize(text2)
# Out:
# ["'Of course it's only because Tom isn't home,' said Mrs. Parsons vaguely."]

# %% [markdown]
# Custom lists of patterns are often necessary for special domains.

# %%
text3 = "An die Stelle der Landesgesetze vom 17. Jänner 1883, n.ö.L.G. u. V.Bl. Nr. 35, vom 26. Dezember 1890, n.ö.L.G. u. V.Bl. Nr. 48, vom 17. Juni 1920 n.ö.L.G. u. V.Bl. Nr. 547, vom 4. November 1920 n.ö.L.G. u. V.Bl. Nr. 808, und vom 9. Dezember 1927, L.G.Bl. für Wien Nr. 1 ex 1928, die, soweit dieses Gesetz nichts anderes bestimmt, zugleich ihre Wirksamkeit verlieren, hat die nachfolgende Bauordnung zu treten."

# %%
print(text3)
# Out:
# An die Stelle der Landesgesetze vom 17. Jänner 1883, n.ö.L.G. u. V.Bl. Nr. 35, vom 26. Dezember 1890, n.ö.L.G. u. V.Bl. Nr. 48, vom 17. Juni 1920 n.ö.L.G. u. V.Bl. Nr. 547, vom 4. November 1920 n.ö.L.G. u. V.Bl. Nr. 808, und vom 9. Dezember 1927, L.G.Bl. für Wien Nr. 1 ex 1928, die, soweit dieses Gesetz nichts anderes bestimmt, zugleich ihre Wirksamkeit verlieren, hat die nachfolgende Bauordnung zu treten.

# %%
nltk.sent_tokenize(text3, language='german')
# Out:
# ['An die Stelle der Landesgesetze vom 17.',
#  'Jänner 1883, n.ö.L.G.',
#  'u. V.Bl.',
#  'Nr. 35, vom 26. Dezember 1890, n.ö.L.G.',
#  'u. V.Bl.',
#  'Nr. 48, vom 17. Juni 1920 n.ö.L.G.',
#  'u. V.Bl.',
#  'Nr. 547, vom 4. November 1920 n.ö.L.G.',
#  'u. V.Bl.',
#  'Nr. 808, und vom 9. Dezember 1927, L.G.Bl.',
#  'für Wien Nr. 1 ex 1928, die, soweit dieses Gesetz nichts anderes bestimmt, zugleich ihre Wirksamkeit verlieren, hat die nachfolgende Bauordnung zu treten.']

# %% [markdown]
# ###  Tokenization

# %% [markdown]
# #### How to  split text into words?

# %% [markdown]
# #### Naive approach: split on whitespace

# %%
text2.split()
# Out:
# ["'Of",
#  'course',
#  "it's",
#  'only',
#  'because',
#  'Tom',
#  "isn't",
#  "home,'",
#  'said',
#  'Mrs.',
#  'Parsons',
#  'vaguely.']

# %% [markdown]
# #### Better: separate punctuation marks

# %%
re.findall('(\w+|[^\w\s]+)', text2)[:30]
# Out:
# ["'",
#  'Of',
#  'course',
#  'it',
#  "'",
#  's',
#  'only',
#  'because',
#  'Tom',
#  'isn',
#  "'",
#  't',
#  'home',
#  ",'",
#  'said',
#  'Mrs',
#  '.',
#  'Parsons',
#  'vaguely',
#  '.']

# %% [markdown]
# #### Best: add some language-specific conventions:

# %%
nltk.word_tokenize(text2)
# Out:
# ["'Of",
#  'course',
#  'it',
#  "'s",
#  'only',
#  'because',
#  'Tom',
#  'is',
#  "n't",
#  'home',
#  ',',
#  "'",
#  'said',
#  'Mrs.',
#  'Parsons',
#  'vaguely',
#  '.']

# %% [markdown]
# ## Text normalization

# %%
words = nltk.word_tokenize(text)

# %%
words[:10]
# Out:
# ['[',
#  '1',
#  ']',
#  'Erstes',
#  'Kapitel',
#  '.',
#  'Hinunter',
#  'in',
#  'den',
#  'Kaninchenbau']

# %%
Counter(words).most_common(10)
# Out:
# [(',', 2617),
#  ('„', 1086),
#  ('“', 1083),
#  ('.', 841),
#  ('sie', 777),
#  ('und', 742),
#  ('die', 620),
#  ('der', 477),
#  ('!', 466),
#  ('zu', 421)]

# %% [markdown]
# Let's get rid of punctuation

# %%
words = [word for word in words if re.match('\w', word)]

# %%
Counter(words).most_common(10)
# Out:
# [('sie', 777),
#  ('und', 742),
#  ('die', 620),
#  ('der', 477),
#  ('zu', 421),
#  ('Alice', 388),
#  ('sagte', 360),
#  ('ich', 355),
#  ('es', 354),
#  ('nicht', 350)]

# %% [markdown]
# Filtering common function words is called __stopword removal__

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords = set(stopwords.words('german'))
print(stopwords)
# Out:
# {'meinen', 'bin', 'jedes', 'selbst', 'welchen', 'nur', 'dein', 'unseres', 'haben', 'eine', 'anderem', 'dich', 'zwischen', 'ein', 'musste', 'einigem', 'einiges', 'was', 'wollen', 'für', 'kein', 'vor', 'einen', 'könnte', 'mir', 'aber', 'unserem', 'euer', 'bei', 'einig', 'wir', 'etwas', 'denn', 'anderer', 'aller', 'andern', 'eures', 'manchem', 'einigen', 'hat', 'dies', 'seiner', 'warst', 'allen', 'anderen', 'allem', 'ins', 'eurem', 'waren', 'jenen', 'vom', 'hin', 'wird', 'diesen', 'meines', 'man', 'nichts', 'so', 'unser', 'als', 'du', 'da', 'alle', 'sehr', 'wollte', 'bis', 'es', 'dir', 'zur', 'anderr', 'machen', 'oder', 'sondern', 'jeden', 'mich', 'eurer', 'bist', 'wie', 'jene', 'keiner', 'hatte', 'weil', 'sein', 'solchen', 'unter', 'er', 'jenem', 'durch', 'gewesen', 'sie', 'der', 'um', 'indem', 'ohne', 'sind', 'soll', 'in', 'keine', 'einer', 'viel', 'sich', 'mein', 'sonst', 'deiner', 'jedem', 'habe', 'gegen', 'welche', 'jeder', 'welches', 'nach', 'weiter', 'einige', 'unseren', 'werde', 'will', 'hatten', 'dann', 'anders', 'manche', 'anderes', 'ihren', 'manches', 'ihn', 'seinen', 'solchem', 'hab', 'solches', 'den', 'am', 'welcher', 'ihm', 'dasselbe', 'des', 'keinem', 'an', 'ander', 'dazu', 'sollte', 'nun', 'deinen', 'hier', 'keinen', 'seines', 'ihr', 'seinem', 'seine', 'uns', 'würde', 'dieser', 'ihres', 'zu', 'das', 'über', 'während', 'alles', 'eines', 'anderm', 'daß', 'diesem', 'wenn', 'euren', 'und', 'hinter', 'mit', 'eure', 'damit', 'auch', 'dass', 'deine', 'einem', 'jener', 'meine', 'meinem', 'solcher', 'deines', 'andere', 'manchen', 'demselben', 'weg', 'ihrem', 'ist', 'ob', 'euch', 'werden', 'jenes', 'derselbe', 'dieses', 'doch', 'derselben', 'kann', 'können', 'meiner', 'wieder', 'zum', 'welchem', 'wo', 'derer', 'diese', 'nicht', 'mancher', 'zwar', 'auf', 'ihre', 'von', 'desselben', 'aus', 'also', 'jetzt', 'im', 'unsere', 'dieselben', 'würden', 'war', 'dieselbe', 'deinem', 'einmal', 'ich', 'jede', 'dem', 'dessen', 'einiger', 'keines', 'ihnen', 'solche', 'dort', 'die', 'noch', 'wirst', 'muss', 'ihrer', 'denselben'}
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
words = [word for word in words if word.lower() not in stopwords]

# %%
Counter(words).most_common(20)
# Out:
# [('Alice', 388),
#  ('sagte', 360),
#  ('ganz', 79),
#  ('Königin', 72),
#  ('dachte', 65),
#  ('sprach', 62),
#  ('König', 58),
#  ('fort', 53),
#  ('Hutmacher', 53),
#  ('Schildkröte', 53),
#  ('s', 52),
#  ('konnte', 51),
#  ('fing', 47),
#  ('sah', 47),
#  ('falsche', 45),
#  ('Kaninchen', 44),
#  ('wohl', 44),
#  ('sehen', 43),
#  ('Herzogin', 42),
#  ('fragte', 40)]

# %% [markdown]
# ### Lemmatization and stemming
#
# Words like _say_, _says_, and _said_ are all different **word forms** of the same **lemma**. Grouping them together can be useful in many applications.

# %% [markdown]
# **Stemming** is the reduction of words to a common prefix, using simple rules that only work some of the time:

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('german')

# %%
for word in ('sagen', 'sag', 'gesagt'):
    print(stemmer.stem(word, ))
# Out:
# sag
# sag
# gesagt

# %%
for word in ('er', 'sein', 'ihm'):
    print(stemmer.stem(word))
# Out:
# er
# sein
# ihm

# %% [markdown]
# **Lemmatization** is the mapping of word forms to their lemma, using either a dictionary of word forms, a grammar of how words are formed (a **morphology**), or both.

# %%
stanza.download('de')
nlp_de = stanza.Pipeline('de', processors='tokenize,lemma,pos')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-10-14 19:21:11 INFO: Downloading default packages for language: de (German)...
# 2021-10-14 19:21:12 INFO: File exists: /home/jovyan/stanza_resources/de/default.zip.
# 2021-10-14 19:21:18 INFO: Finished downloading models and saved to /home/jovyan/stanza_resources.
# 2021-10-14 19:21:18 WARNING: Language de package default expects mwt, which has been added
# 2021-10-14 19:21:18 INFO: Loading these models for language: de (German):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# =======================
#
# 2021-10-14 19:21:18 INFO: Use device: cpu
# 2021-10-14 19:21:18 INFO: Loading: tokenize
# 2021-10-14 19:21:18 INFO: Loading: mwt
# 2021-10-14 19:21:18 INFO: Loading: pos
# 2021-10-14 19:21:18 INFO: Loading: lemma
# 2021-10-14 19:21:18 INFO: Done loading processors!

# %%
doc_de = nlp_de(text)
# Out:
# /opt/conda/lib/python3.9/site-packages/torch/_tensor.py:575: UserWarning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (Triggered internally at  ../aten/src/ATen/native/BinaryOps.cpp:467.)
#   return torch.floor_divide(self, other)

# %%
for sentence in doc_de.sentences[:5]:
    for word in sentence.words:
        print(word.text + '\t' + word.lemma)
    print()
# Out:
# [1	[1
# ]	]
# Erstes	erst
# Kapitel	Kapitel
# .	.
#
# Hinunter	Hinunter
# in	in
# den	der
# Kaninchenbau	Kaninchenbau
# .	.
#
# Alice	Alice
# fing	fangen
# an	an
# sich	er|es|sie
# zu	zu
# langweilen	langweilen
# ;	;
#
# sie	sie
# saß	sitzen
# schon	schon
# lange	lange
# bei	bei
# ihrer	ihr
# Schwester	Schwester
# an	an
# dem	der
# Ufer	Ufer
# und	und
# hatte	haben
# nichts	nichts
# zu	zu
# thun	than
# .	.
#
# Das	der
# Buch	Buch
# ,	,
# das	der
# ihre	ihr
# Schwester	Schwester
# las	lesen
# ,	,
# gefiel	gefallen
# ihr	ihr
# nicht	nicht
# ;	;

# %% [markdown]
# Now we can count lemmas

# %%
Counter(
    word.lemma for sentence in doc_de.sentences for word in sentence.words
    if word.lemma not in stopwords and re.match('\w', word.lemma)).most_common(20)
# Out:
# [('sagen', 430),
#  ('Alice', 388),
#  ('er|es|sie', 287),
#  ('sehen', 143),
#  ('kommen', 113),
#  ('ganz', 110),
#  ('Sie|sie', 108),
#  ('klein', 96),
#  ('denken', 79),
#  ('gehen', 79),
#  ('sprechen', 78),
#  ('Königin', 74),
#  ('müssen', 73),
#  ('groß', 70),
#  ('gut', 62),
#  ('König', 62),
#  ('fragen', 57),
#  ('fort', 56),
#  ('falsch', 56),
#  ('fangen', 55)]

# %% [markdown]
# The full analysis of how a word form is built from its lemma is known as **morphological analysis**

# %%
for sentence in doc_de.sentences[:5]:
    for word in sentence.words:
        print('\t'.join([word.text, word.lemma, word.upos, word.feats if word.feats else '']))
    print()
# Out:
# [1	[1	PUNCT
# ]	]	PUNCT
# Erstes	erst	ADJ	Case=Nom|Gender=Neut|Number=Sing
# Kapitel	Kapitel	NOUN	Case=Nom|Gender=Neut|Number=Sing
# .	.	PUNCT
#
# Hinunter	Hinunter	NOUN	Case=Nom|Gender=Masc|Number=Sing
# in	in	ADP
# den	der	DET	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|PronType=Art
# Kaninchenbau	Kaninchenbau	PROPN	Case=Acc|Gender=Masc|Number=Sing
# .	.	PUNCT
#
# Alice	Alice	PROPN	Case=Nom|Gender=Masc|Number=Sing
# fing	fangen	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# an	an	ADP
# sich	er|es|sie	PRON	Case=Acc|Number=Sing|Person=3|PronType=Prs|Reflex=Yes
# zu	zu	PART
# langweilen	langweilen	VERB	VerbForm=Inf
# ;	;	PUNCT
#
# sie	sie	PRON	Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# saß	sitzen	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# schon	schon	ADV
# lange	lange	ADV
# bei	bei	ADP
# ihrer	ihr	DET	Case=Dat|Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# Schwester	Schwester	NOUN	Case=Dat|Gender=Fem|Number=Sing
# an	an	ADP
# dem	der	DET	Case=Dat|Definite=Def|Gender=Neut|Number=Sing|PronType=Art
# Ufer	Ufer	NOUN	Case=Dat|Gender=Neut|Number=Sing
# und	und	CCONJ
# hatte	haben	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# nichts	nichts	PRON	Definite=Ind|PronType=Ind
# zu	zu	PART
# thun	than	VERB	VerbForm=Inf
# .	.	PUNCT
#
# Das	der	DET	Case=Nom|Definite=Def|Gender=Neut|Number=Sing|PronType=Art
# Buch	Buch	NOUN	Case=Nom|Gender=Neut|Number=Sing
# ,	,	PUNCT
# das	der	PRON	Case=Nom|Gender=Neut|Number=Sing|PronType=Rel
# ihre	ihr	DET	Case=Acc|Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs
# Schwester	Schwester	NOUN	Case=Acc|Gender=Fem|Number=Sing
# las	lesen	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
# ,	,	PUNCT
# gefiel	gefallen	VERB	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
# ihr	ihr	PRON	Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
# nicht	nicht	PART	Polarity=Neg
# ;	;	PUNCT

# %% [markdown]
# A special case of lemmatization is **decompounding**, recognizing multiple lemmas in a word

# %%
nlp_de('Achterbahn')
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Achterbahn",
#       "lemma": "Achterbahn",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing",
#       "start_char": 0,
#       "end_char": 10
#     }
#   ]
# ]

# %%
nlp_de('Mülleimer')
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Mülleimer",
#       "lemma": "Mülleimer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Masc|Number=Plur",
#       "start_char": 0,
#       "end_char": 9
#     }
#   ]
# ]

# %% [markdown]
# For English you might say that this is good enough... but _some languages_ allow forming compounds on the fly...

# %%
stanza.download('de')
nlp_de = stanza.Pipeline('de', processors='tokenize,lemma,pos')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2021-10-14 19:20:50 INFO: Downloading default packages for language: de (German)...
# 2021-10-14 19:20:52 INFO: File exists: /home/jovyan/stanza_resources/de/default.zip.
# 2021-10-14 19:20:57 INFO: Finished downloading models and saved to /home/jovyan/stanza_resources.
# 2021-10-14 19:20:57 WARNING: Language de package default expects mwt, which has been added
# 2021-10-14 19:20:57 INFO: Loading these models for language: de (German):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# =======================
#
# 2021-10-14 19:20:57 INFO: Use device: cpu
# 2021-10-14 19:20:57 INFO: Loading: tokenize
# 2021-10-14 19:20:57 INFO: Loading: mwt
# 2021-10-14 19:20:57 INFO: Loading: pos
# 2021-10-14 19:20:57 INFO: Loading: lemma
# 2021-10-14 19:20:57 INFO: Done loading processors!

# %%
nlp_de('Kassenidentifikationsnummer')
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Kassenidentifikationsnummer",
#       "lemma": "Kassenidentifikationsnummer",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Case=Nom|Gender=Fem|Number=Sing",
#       "start_char": 0,
#       "end_char": 27
#     }
#   ]
# ]

# %% [markdown]
# There is no good generic solution and no standard tool. There are some unsupervised approaches like [SECOS](https://github.com/riedlma/SECOS) and [CharSplit](https://github.com/dtuggener/CharSplit), and there are also full-fledged morphological analyzers that might work, like [SMOR](https://www.cis.lmu.de/~schmid/tools/SMOR/) and its extensions [zmorge](https://pub.cl.uzh.ch/users/sennrich/zmorge/) and [SMORLemma](https://github.com/rsennrich/SMORLemma).

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Text processing with regular expressions

# %% [markdown]
# Load a sample text

# %%
text = open('data/alice_de.txt').read()
print(text[:1000])
# Out:
# [1] Erstes Kapitel.
#
# Hinunter in den Kaninchenbau.
#
# Alice fing an sich zu langweilen; sie saß schon lange bei ihrer Schwester am Ufer und hatte nichts zu thun. Das Buch, das ihre Schwester las, gefiel ihr nicht; denn es waren weder Bilder noch [2] Gespräche darin. „Und was nützen Bücher,“ dachte Alice, „ohne Bilder und Gespräche?“
#
# Sie überlegte sich eben, (so gut es ging, denn sie war schläfrig und dumm von der Hitze,) ob es der Mühe werth sei aufzustehen und Gänseblümchen zu pflücken, um eine Kette damit zu machen, als plötzlich ein weißes Kaninchen mit rothen Augen dicht an ihr vorbeirannte.
#
# Dies war grade nicht sehr merkwürdig; Alice fand es auch nicht sehr außerordentlich, daß sie das Kaninchen sagen hörte: „O weh, o weh! Ich werde zu spät kommen!“ (Als sie es später wieder überlegte, fiel ihr ein, daß sie sich darüber hätte wundern sollen; doch zur Zeit kam es ihr Alles ganz natürlich vor.) Aber als das Kaninchen seine Uhr aus der Westentasche zog, nach der Zeit sah und eilig fo

# %%
def clean_text(text):
    cleaned_text = re.sub('_','',text)
    cleaned_text = re.sub('\n', ' ', cleaned_text)
    return cleaned_text

# %%
text = clean_text(text)

# %%
print(text[:1000])
# Out:
# [1] Erstes Kapitel.  Hinunter in den Kaninchenbau.  Alice fing an sich zu langweilen; sie saß schon lange bei ihrer Schwester am Ufer und hatte nichts zu thun. Das Buch, das ihre Schwester las, gefiel ihr nicht; denn es waren weder Bilder noch [2] Gespräche darin. „Und was nützen Bücher,“ dachte Alice, „ohne Bilder und Gespräche?“  Sie überlegte sich eben, (so gut es ging, denn sie war schläfrig und dumm von der Hitze,) ob es der Mühe werth sei aufzustehen und Gänseblümchen zu pflücken, um eine Kette damit zu machen, als plötzlich ein weißes Kaninchen mit rothen Augen dicht an ihr vorbeirannte.  Dies war grade nicht sehr merkwürdig; Alice fand es auch nicht sehr außerordentlich, daß sie das Kaninchen sagen hörte: „O weh, o weh! Ich werde zu spät kommen!“ (Als sie es später wieder überlegte, fiel ihr ein, daß sie sich darüber hätte wundern sollen; doch zur Zeit kam es ihr Alles ganz natürlich vor.) Aber als das Kaninchen seine Uhr aus der Westentasche zog, nach der Zeit sah und eilig fo

# %% [markdown]
# Let's split this into sentences, then words.

# %%
sens = sent_tokenize(text)

# %%
print('\n\n'.join(sens[:5]))
# Out:
# [1] Erstes Kapitel.
#
# Hinunter in den Kaninchenbau.
#
# Alice fing an sich zu langweilen; sie saß schon lange bei ihrer Schwester am Ufer und hatte nichts zu thun.
#
# Das Buch, das ihre Schwester las, gefiel ihr nicht; denn es waren weder Bilder noch [2] Gespräche darin.
#
# „Und was nützen Bücher,“ dachte Alice, „ohne Bilder und Gespräche?“  Sie überlegte sich eben, (so gut es ging, denn sie war schläfrig und dumm von der Hitze,) ob es der Mühe werth sei aufzustehen und Gänseblümchen zu pflücken, um eine Kette damit zu machen, als plötzlich ein weißes Kaninchen mit rothen Augen dicht an ihr vorbeirannte.

# %%
toks = [word_tokenize(sen) for sen in sens]

# %%
print('\n\n'.join('\n'.join(sen) for sen in toks[:5]))
# Out:
# [
# 1
# ]
# Erstes
# Kapitel
# .
#
# Hinunter
# in
# den
# Kaninchenbau
# .
#
# Alice
# fing
# an
# sich
# zu
# langweilen
# ;
# sie
# saß
# schon
# lange
# bei
# ihrer
# Schwester
# am
# Ufer
# und
# hatte
# nichts
# zu
# thun
# .
#
# Das
# Buch
# ,
# das
# ihre
# Schwester
# las
# ,
# gefiel
# ihr
# nicht
# ;
# denn
# es
# waren
# weder
# Bilder
# noch
# [
# 2
# ]
# Gespräche
# darin
# .
#
# „
# Und
# was
# nützen
# Bücher
# ,
# “
# dachte
# Alice
# ,
# „
# ohne
# Bilder
# und
# Gespräche
# ?
# “
# Sie
# überlegte
# sich
# eben
# ,
# (
# so
# gut
# es
# ging
# ,
# denn
# sie
# war
# schläfrig
# und
# dumm
# von
# der
# Hitze
# ,
# )
# ob
# es
# der
# Mühe
# werth
# sei
# aufzustehen
# und
# Gänseblümchen
# zu
# pflücken
# ,
# um
# eine
# Kette
# damit
# zu
# machen
# ,
# als
# plötzlich
# ein
# weißes
# Kaninchen
# mit
# rothen
# Augen
# dicht
# an
# ihr
# vorbeirannte
# .

# %% [markdown]
# Let's also write this to a file

# %%
with open('data/alice_tok_de.txt', 'w') as f:
    f.write('\n\n'.join('\n'.join(sen) for sen in toks) + '\n')

# %% [markdown]
# Let's try to find all names using regexes

# %%
def find_names(toks):
    curr_name = []
    for sen in toks:
        for tok in sen[1:]:
            if re.match('[A-Z][a-z]+', tok):
                curr_name.append(tok)
            elif curr_name:
                yield ' '.join(curr_name)
                curr_name = []
                
        if curr_name:
            yield curr_name
            
        
def count_names(toks):
    name_counter = Counter()
    
    for name in find_names(toks):
        name_counter[name] += 1
    
    for name, count in name_counter.most_common():
        print(name, count)

# %%
count_names(toks)
# Out:
# Alice 334
# Ich 107
# Sie 62
# Hutmacher 51
# Schildkröte 51
# Es 49
# Das 45
# Und 43
# Kaninchen 41
# Herzogin 41
# Stimme 38
# Greif 38
# Zeit 36
# Alles 36
# Kopf 36
# Murmelthier 34
# Maus 32
# Raupe 31
# Was 30
# Aber 30
# Thür 28
# Wie 27
# Du 27
# Katze 26
# Augen 25
# Faselhase 24
# Augenblick 23
# Hand 23
# Tone 22
# Alle 20
# Nein 19
# Mal 18
# Frage 17
# Geschwornen 17
# Kind 16
# Ja 16
# Wenn 16
# Worte 15
# Gesicht 15
# Wabbel 15
# Fall 14
# Minuten 14
# Ende 14
# Dann 14
# Nun 13
# Dinah 13
# Fuß 13
# Geschichte 13
# Dodo 13
# Papagei 13
# Seite 12
# Kuchen 12
# Arm 12
# Ihr 12
# Taube 12
# Als 11
# Katzen 11
# Garten 11
# Leben 11
# Text 11
# Quelle Korrektur 11
# Schreibweise 11
# Originaltext 11
# Oh 11
# Die 11
# Platz 11
# Tag 11
# Uhr 10
# Niemand 10
# Wort 10
# Luft 10
# Hause 10
# Er 10
# Thee 10
# Soldaten 10
# Igel 10
# Greifen 10
# Tanz 10
# Hals 9
# Ding 9
# So 9
# Da 9
# Wir 9
# Unterhaltung 9
# Gesellschaft 9
# Sinn 9
# Mund 9
# Moral 9
# Schwester 8
# Haus 8
# Gelegenheit 8
# Worten 8
# In 8
# Antwort 8
# Verhör 8
# Fenster 8
# Wer 8
# Ferkel 8
# Gedanken 7
# Schule 7
# Hier 7
# Größe 7
# Thränen 7
# Kinder 7
# Komm 7
# Kinn 7
# Hund 7
# Spiel 7
# Ach 7
# Leute 7
# Schlange 7
# Pfeffer 7
# Lackei 7
# Nase 7
# Warum 7
# Eure Majestät 7
# Henker 7
# Welt 6
# Entfernung 6
# Kopfe 6
# Spatzen 6
# Tische 6
# Zoll 6
# Croquet 6
# Art 6
# Bei 6
# See 6
# Verzeihung 6
# Stelle 6
# Thiere 6
# Andern 6
# Fertig 6
# Reihe 6
# Teller 6
# Bemerkung 6
# Stunden 6
# Recht 6
# Flamingo 6
# Schlagt 6
# Hummer 6
# Tafeln 6
# Ufer 5
# Brunnen 5
# Traum 5
# Male 5
# Corridor 5
# Seiten 5
# Mitte 5
# Schlüsselchen 5
# Denn 5
# Tisch 5
# Finger 5
# Flasche 5
# That 5
# Auge 5
# Weilchen 5
# Bitte 5
# Handschuhe 5
# Vielleicht 5
# Angst 5
# Gegenstand 5
# Namen 5
# Liebe 5
# Chor 5
# Nur 5
# Schwanz 5
# Zeugen 5
# Jemand 5
# Dies 5
# Eidechse 5
# Stück 5
# Huhka 5
# Anfang 5
# Tage 5
# Doch 5
# Mann 5
# Eier 5
# Paar Minuten 5
# Gesichte 5
# Arme 5
# Einen 5
# Suppe 5
# Ohr 5
# Den 5
# Natürlich 5
# Zwei 5
# Syrup 5
# Bogen 5
# Hummerballet 5
# Weißfisch 5
# Erde 4
# Land 4
# Gang 4
# Ecke 4
# Ohren 4
# Schlüssel 4
# Fläschchen 4
# Freunde 4
# Beispiel 4
# Still 4
# Person 4
# Dabei 4
# Dinge 4
# Paar 4
# Unsinn 4
# Gerade 4
# Pfuhl 4
# Eile 4
# Nacht 4
# Clara 4
# Mit 4
# Kaninchens 4
# Wasser 4
# Augenblicke 4
# Thier 4
# Pfoten 4
# Fell 4
# Geschöpfe 4
# Versammlung 4
# Athem 4
# Jeder 4
# Tasche 4
# Zeuge 4
# Laune 4
# Richtung 4
# Zimmer 4
# Ellbogen 4
# Euer Jnaden 4
# Zu 4
# Acht 4
# Schornstein 4
# Fuße 4
# Entzücken 4
# Meerschweinchen 4
# Weg 4
# Pfote 4
# Stäbchen 4
# Munde 4
# Sage 4
# Lackeien 4
# Muth 4
# Jungen 4
# Grinsen 4
# Faselhasen 4
# Sehr 4
# Schulter 4
# Lied 4
# Seufzer 4
# Butterbrot 4
# Auf 4
# Rosenstrauch 4
# Sieben 4
# Knie 4
# Spiele 4
# Schluchzen 4
# Vervielfraßen 4
# Supp 4
# Su–uppe 4
# Geschworne 4
# Urtheil 4
# Aussage 4
# Papier 4
# Kaninchenbau 3
# Buch 3
# Bilder 3
# Neugierde 3
# Eingang 3
# Verdruß 3
# Treppe 3
# Meilen 3
# Begriff 3
# Decke 3
# Glas 3
# Gedanke 3
# Gange 3
# Schultern 3
# Teleskop 3
# Merkwürdiges 3
# Todtenkopf 3
# Kindern 3
# Weile 3
# Personen 3
# Gut 3
# Jetzt 3
# Schuhe 3
# Kamin 3
# Herr 3
# Menge 3
# Wirthe 3
# Erstaunen 3
# Glastische 3
# Pfuhle 3
# Die Maus 3
# Wilhelm 3
# Feuer 3
# Bewegung 3
# Ente 3
# Adler 3
# Sache 3
# Krone 3
# Noch 3
# Preise 3
# Versteht 3
# Fingerhut 3
# Gericht 3
# Richter 3
# Halt 3
# Vogel 3
# Marianne 3
# Aussicht 3
# Schrei 3
# Geklirr 3
# Wo 3
# Pause 3
# Dach 3
# Nimm 3
# Nicht 3
# Schweigen 3
# Plan 3
# Ferne 3
# Pilz 3
# Sommertage 1

# %% [markdown]
# We can filter our tokens for stopwords:

# %%
toks_without_stopwords = [[tok for tok in sen if tok.lower() not in stopwords] for sen in toks]

# %%
print('\n\n'.join('\n'.join(sen) for sen in toks_without_stopwords[:5]))
# Out:
# [
# 1
# ]
# Erstes
# Kapitel
# .
#
# Hinunter
# Kaninchenbau
# .
#
# Alice
# fing
# langweilen
# ;
# saß
# schon
# lange
# Schwester
# Ufer
# thun
# .
#
# Buch
# ,
# Schwester
# las
# ,
# gefiel
# ;
# weder
# Bilder
# [
# 2
# ]
# Gespräche
# darin
# .
#
# „
# nützen
# Bücher
# ,
# “
# dachte
# Alice
# ,
# „
# Bilder
# Gespräche
# ?
# “
# überlegte
# eben
# ,
# (
# gut
# ging
# ,
# schläfrig
# dumm
# Hitze
# ,
# )
# Mühe
# werth
# sei
# aufzustehen
# Gänseblümchen
# pflücken
# ,
# Kette
# ,
# plötzlich
# weißes
# Kaninchen
# rothen
# Augen
# dicht
# vorbeirannte
# .

# %%
count_names(toks_without_stopwords)
# Out:
# Alice 307
# Hutmacher 44
# Schildkröte 42
# Greif 38
# Kaninchen 37
# Zeit 32
# Herzogin 32
# Maus 32
# Stimme 31
# Murmelthier 28
# Raupe 25
# Augen 22
# Faselhase 22
# Thür 20
# Kopf 19
# Nein 19
# Tone 19
# Katze 19
# Augenblick 17
# Ja 16
# Worte 15
# Frage 15
# Mal 15
# Kind 15
# Gesicht 14
# Wabbel 14
# Geschwornen 14
# Minuten 12
# Kuchen 12
# Papagei 12
# Quelle Korrektur 11
# Originaltext 11
# Fuß 11
# Oh 11
# Dodo 11
# Taube 11
# Majestät 11
# Fall 10
# Wort 10
# Dinah 10
# Garten 10
# Geschichte 10
# Tanz 10
# Ding 9
# Hause 9
# Verhör 9
# Gelegenheit 8
# Niemand 8
# Katzen 8
# Hand 8
# Leben 8
# Platz 8
# Thee 8
# Haus 7
# Seite 7
# Größe 7
# Komm 7
# Ach 7
# Wer 7
# Tag 7
# Pfeffer 7
# Soldaten 7
# Igel 7
# Moral 7
# Schule 6
# Kopfe 6
# Luft 6
# Spatzen 6
# Zoll 6
# Worten 6
# Thränen 6
# Kinder 6
# Gesellschaft 6
# Liebe 6
# Sinn 6
# Antwort 6
# Hals 6
# Fertig 6
# Leute 6
# Arm 6
# Schlange 6
# Lackei 6
# Nase 6
# Ferkel 6
# Uhr 6
# Warum 6
# Schlagt Kopf 6
# Schwester 5
# Brunnen 5
# Traum 5
# Tische 5
# Schlüsselchen 5
# Gedanken 5
# Croquet 5
# Handschuhe 5
# Vielleicht 5
# Verzeihung 5
# Hund 5
# Thiere 5
# Art 5
# Chor 5
# Unterhaltung 5
# Ende 5
# Mund 5
# Eier 5
# Paar Minuten 5
# Gesichte 5
# Teller 5
# Bemerkung 5
# Stunden 5
# Ohr 5
# Natürlich 5
# Zwei 5
# Syrup 5
# Recht 5
# Spiel 5
# Henker 5
# Tafeln 5
# Gang 4
# Corridor 4
# Mitte 4
# Schlüssel 4
# Still 4
# Dabei 4
# Unsinn 4
# Bitte 4
# Clara 4
# See 4
